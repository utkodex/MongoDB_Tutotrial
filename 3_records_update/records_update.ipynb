# %%
from pymongo import MongoClient

client = MongoClient('mongodb://127.0.0.1:27017/')

mydb = client['Library']
books_info = mydb['books_info']

# %%
books_info.insert_many([
    {
        "title": "Introduction to Algorithms",
        "author": "Thomas H. Cormen",
        "copies": 50,
        "size": {"height": 24, "width": 18, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "Clean Code",
        "author": "Robert C. Martin",
        "copies": 30,
        "size": {"height": 23, "width": 16, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "The Pragmatic Programmer",
        "author": "Andrew Hunt",
        "copies": 40,
        "size": {"height": 25, "width": 17, "unit": "cm"},
        "status": "borrowed"
    },
    {
        "title": "Design Patterns",
        "author": "Erich Gamma",
        "copies": 20,
        "size": {"height": 26, "width": 19, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "You Don’t Know JS",
        "author": "Kyle Simpson",
        "copies": 35,
        "size": {"height": 20, "width": 15, "unit": "cm"},
        "status": "reserved"
    },
    {
        "title": "JavaScript: The Good Parts",
        "author": "Douglas Crockford",
        "copies": 15,
        "size": {"height": 22, "width": 14, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "Effective Java",
        "author": "Joshua Bloch",
        "copies": 45,
        "size": {"height": 24, "width": 18, "unit": "cm"},
        "status": "borrowed"
    },
    {
        "title": "Head First Design Patterns",
        "author": "Eric Freeman",
        "copies": 25,
        "size": {"height": 28, "width": 22, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "Python Crash Course",
        "author": "Eric Matthes",
        "copies": 50,
        "size": {"height": 24, "width": 18, "unit": "cm"},
        "status": "reserved"
    },
    {
        "title": "Fluent Python",
        "author": "Luciano Ramalho",
        "copies": 35,
        "size": {"height": 26, "width": 19, "unit": "cm"},
        "status": "available"
    },
    {
        "title": "Artificial Intelligence: A Modern Approach",
        "author": "Stuart Russell",
        "copies": 40,
        "size": {"height": 25, "width": 18, "unit": "cm"},
        "status": "borrowed"
    },
    {
        "title": "Computer Networking: A Top-Down Approach",
        "author": "Kurose and Ross",
        "copies": 60,
        "size": {"height": 27, "width": 20, "unit": "cm"},
        "status": "available"
    }
])
# Out:
# InsertManyResult([ObjectId('684da16ca4f05d3764e231b2'), ObjectId('684da16ca4f05d3764e231b3'), ObjectId('684da16ca4f05d3764e231b4'), ObjectId('684da16ca4f05d3764e231b5'), ObjectId('684da16ca4f05d3764e231b6'), ObjectId('684da16ca4f05d3764e231b7'), ObjectId('684da16ca4f05d3764e231b8'), ObjectId('684da16ca4f05d3764e231b9'), ObjectId('684da16ca4f05d3764e231ba'), ObjectId('684da16ca4f05d3764e231bb'), ObjectId('684da16ca4f05d3764e231bc'), ObjectId('684da16ca4f05d3764e231bd')], acknowledged=True)

# %% [markdown]
# ## Update one

# %%
books_info.update_one(
    {"title": "Artificial Intelligence: A Modern Approach"},
    {"$set": {"size.unit": "m", "status": "unavailable"},
    "$currentDate": {"lastModified": True}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Update Many

# %%
books_info.update_many(
    {"copies": {"$lt": 23}},
    {"$set": {"size.unit": "in", "status": "less available"},
    "$currentDate": {"lastModified": True}}
)
# Out:
# UpdateResult({'n': 2, 'nModified': 2, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Replace One --> Also changed the Schema to Array

# %%
books_info.replace_one(
    {"title": "Head First Design Patterns"},
    {"title": "Head First Design Patterns",
        "box": [
            {"height": 280, "width": 2, "unit": "ft"},
            {"room": 7, "row": 20}
            ],
        "box status": "too long"}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# #### Before replace

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### After replace

# %% [markdown]
# ![image.png](attachment:image.png)
