# %% [markdown]
# ## PIP Installs

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.13.1-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.13.1-cp310-cp310-win_amd64.whl (800 kB)
#    ---------------------------------------- 0.0/800.1 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/800.1 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 800.1/800.1 kB 4.3 MB/s eta 0:00:00
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Insert one data point

# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://127.0.0.1:27017/')

# Create or access a database
mydb = client['Student']

# Create or access a collection
information = mydb['studentinformation']

# Insert sample data (as a single document, not a list)
student_data = {"name": "Alice", "age": 25, "city": "New York"}

# Use insert_one to insert the document
information.insert_one(student_data)
# Out:
# InsertOneResult(ObjectId('684d5bc601556ae142976edd'), acknowledged=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Verify data insertion
for document in information.find():
    print(document)
# Out:
# {'_id': ObjectId('684d5bc601556ae142976edd'), 'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# ## Insert more than one data

# %%
# Create or access a database
mydb = client['employee']

# Create or access a collection
information = mydb['employeeinformation']

# Insert sample data (as a single document, not a list)
employee_data = [
    {"name": "Alice", "age": 25, "city": "New York"},
    {"name": "Bob", "age": 30, "city": "San Francisco"},
    {"name": "Charlie", "age": 35, "city": "Los Angeles"},
    {"name": "David", "age": 40, "city": "Chicago"},
    {"name": "Eve", "age": 28, "city": "Seattle"}
]

# Use insert_one to insert the document
information.insert_many(employee_data)
# Out:
# InsertManyResult([ObjectId('684d5bcc01556ae142976ede'), ObjectId('684d5bcc01556ae142976edf'), ObjectId('684d5bcc01556ae142976ee0'), ObjectId('684d5bcc01556ae142976ee1'), ObjectId('684d5bcc01556ae142976ee2')], acknowledged=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for document in information.find():
    print(document)
# Out:
# {'_id': ObjectId('684d598457107b706525be25'), 'name': 'Alice', 'age': 25, 'city': 'New York'}
# {'_id': ObjectId('684d598457107b706525be26'), 'name': 'Bob', 'age': 30, 'city': 'San Francisco'}
# {'_id': ObjectId('684d598457107b706525be27'), 'name': 'Charlie', 'age': 35, 'city': 'Los Angeles'}
# {'_id': ObjectId('684d598457107b706525be28'), 'name': 'David', 'age': 40, 'city': 'Chicago'}
# {'_id': ObjectId('684d598457107b706525be29'), 'name': 'Eve', 'age': 28, 'city': 'Seattle'}
# {'_id': ObjectId('684d5bcc01556ae142976ede'), 'name': 'Alice', 'age': 25, 'city': 'New York'}
# {'_id': ObjectId('684d5bcc01556ae142976edf'), 'name': 'Bob', 'age': 30, 'city': 'San Francisco'}
# {'_id': ObjectId('684d5bcc01556ae142976ee0'), 'name': 'Charlie', 'age': 35, 'city': 'Los Angeles'}
# {'_id': ObjectId('684d5bcc01556ae142976ee1'), 'name': 'David', 'age': 40, 'city': 'Chicago'}
# {'_id': ObjectId('684d5bcc01556ae142976ee2'), 'name': 'Eve', 'age': 28, 'city': 'Seattle'}
